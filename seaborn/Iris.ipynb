# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 

import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe(include='all').T
# Out:
#               count unique     top freq      mean       std  min  25%   50%  \
# sepal_length  150.0    NaN     NaN  NaN  5.843333  0.828066  4.3  5.1   5.8
# sepal_width   150.0    NaN     NaN  NaN  3.057333  0.435866  2.0  2.8   3.0
# petal_length  150.0    NaN     NaN  NaN     3.758  1.765298  1.0  1.6  4.35
# petal_width   150.0    NaN     NaN  NaN  1.199333  0.762238  0.1  0.3   1.3
# species         150      3  setosa   50       NaN       NaN  NaN  NaN   NaN
#
#               75%  max
# sepal_length  6.4  7.9
# sepal_width   3.3  4.4
# petal_length  5.1  6.9
# petal_width   1.8  2.5
# species       NaN  NaN

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby('species')['petal_length'].sum()
# Out:
# species
# setosa         73.1
# versicolor    213.0
# virginica     272.5
# Name: petal_length, dtype: float64

# %%
df.groupby(['species','sepal_width'])['petal_length'].sum()
# Out:
# species     sepal_width
# setosa      2.3             1.3
#             2.9             1.4
#             3.0             8.2
#             3.1             6.1
#             3.2             6.8
#             3.3             3.1
#             3.4            14.1
#             3.5             8.5
#             3.6             3.8
#             3.7             4.5
#             3.8             6.7
#             3.9             3.0
#             4.0             1.2
#             4.1             1.5
#             4.2             1.4
#             4.4             1.5
# versicolor  2.0             3.5
#             2.2             8.5
#             2.3            11.7
#             2.4            10.8
#             2.5            15.8
#             2.6            11.9
#             2.7            21.2
#             2.8            26.7
#             2.9            30.2
#             3.0            35.5
#             3.1            14.0
#             3.2            14.0
# ...

# %%
df.groupby(['species','petal_length']).agg({'sepal_length':'sum', 'sepal_width':'mean'}).reset_index()
# Out:
#        species  petal_length  sepal_length  sepal_width
# 0       setosa           1.0           4.6     3.600000
# 1       setosa           1.1           4.3     3.000000
# 2       setosa           1.2          10.8     3.600000
# 3       setosa           1.3          33.9     3.228571
# 4       setosa           1.4          63.9     3.353846
# 5       setosa           1.5          66.9     3.569231
# 6       setosa           1.6          34.4     3.342857
# 7       setosa           1.7          21.6     3.600000
# 8       setosa           1.9           9.9     3.600000
# 9   versicolor           3.0           5.1     2.500000
# 10  versicolor           3.3           9.9     2.350000
# 11  versicolor           3.5          10.7     2.300000
# 12  versicolor           3.6           5.6     2.900000
# 13  versicolor           3.7           5.5     2.400000
# 14  versicolor           3.8           5.5     2.400000
# 15  versicolor           3.9          16.6     2.633333
# ...

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df['petal_width'].unique()
# Out:
# array([0.2, 0.4, 0.3, 0.1, 0.5, 0.6, 1.4, 1.5, 1.3, 1.6, 1. , 1.1, 1.8,
#        1.2, 1.7, 2.5, 1.9, 2.1, 2.2, 2. , 2.4, 2.3])

# %%
df['petal_length'].nlargest(1)
# Out:
# 118    6.9
# Name: petal_length, dtype: float64

# %%
df['sepal_length'].nsmallest(1)
# Out:
# 13    4.3
# Name: sepal_length, dtype: float64

# %%
df[df['species'].str.contains('setosa')]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# Name: count, dtype: int64

# %%
df.sort_values(by='petal_width',ascending=False).head(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 109           7.2          3.6           6.1          2.5  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 100           6.3          3.3           6.0          2.5  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 115           6.4          3.2           5.3          2.3  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 141           6.9          3.1           5.1          2.3  virginica

# %%
species_analysis = df.groupby('species')[['petal_length', 'petal_width']].mean()
print('\nSpecies Analysis:\n', species_analysis)
# Out:
# Species Analysis:
#              petal_length  petal_width
# species
# setosa          1.462000     0.246000
# versicolor      4.260000     1.326000
# virginica       5.561224     2.028571

# %%
df.groupby('species').agg({'sepal_length':'mean','petal_length':'mean'})
# Out:
#             sepal_length  petal_length
# species
# setosa          5.006000      1.462000
# versicolor      5.936000      4.260000
# virginica       6.604082      5.561224

# %%
species_analysis = df.groupby('species')[['petal_width', 'sepal_length']].mean()
print('\nSpecies-wise Analysis:\n', species_analysis)
# Out:
# Species-wise Analysis:
#              petal_width  sepal_length
# species
# setosa         0.246000      5.006000
# versicolor     1.326000      5.936000
# virginica      2.028571      6.604082

# %%
sepal_analysis = df.groupby('species')[['sepal_length','sepal_width']].mean()
print('\nsepal Impact:\n', sepal_analysis)
# Out:
# sepal Impact:
#              sepal_length  sepal_width
# species
# setosa          5.006000     3.428000
# versicolor      5.936000     2.770000
# virginica       6.604082     2.979592

# %%
species_analysis = df.groupby('species')[['sepal_length', 'petal_length']].mean()
print('\nsepal vs. petal Analysis:\n', species_analysis)
# Out:
# sepal vs. petal Analysis:
#              sepal_length  petal_length
# species
# setosa          5.006000      1.462000
# versicolor      5.936000      4.260000
# virginica       6.604082      5.561224

# %%
df.groupby('species')['sepal_length'].sum()
# Out:
# species
# setosa        250.3
# versicolor    296.8
# virginica     323.6
# Name: sepal_length, dtype: float64

# %%
ax = sns.barplot(data=df, x='species', y ='sepal_width', estimator='mean', errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10)
ax.plot('versicolor', 3.0, 'r*', markersize=10)
plt.grid()
plt.xlabel('species')
plt.ylabel('sepal_width')
plt.title('Barplot of species')
plt.show()

# %%
sns.countplot(data=df,x='petal_length',hue='species', palette='Set2')
plt.grid(True)
plt.title('Count of species')
plt.show()

# %%
Species = df['species'].value_counts()
Species
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# Name: count, dtype: int64

# %%
plt.pie(Species,labels=Species.index, autopct='%1.f%%', explode=[0,0.1,0], colors=sns.color_palette('Set2'))
plt.legend()
plt.title('Distribution of Species')
plt.show()

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(data=df, x='species', y='sepal_length', alpha = 0.5, marker='*', edgecolor='black',legend=True, sizes=(20, 200))
plt.title('Scatter Plot of species')
plt.show()

# %%
sns.lineplot(data=df,x='sepal_length', y='sepal_width',hue='species', orient="x", marker='*', markersize=10, linestyle=':')
plt.title('Line Plot of Sepal length')
plt.show()

# %%
sns.boxplot(data=df, y='petal_length', fill=True, palette='Set2')
plt.title('Box Plot of petal length')
plt.show()

# %%
sns.distplot(df['sepal_width'], hist=True, bins=30, color='b', kde=True, vertical=False)
plt.title('dtribution Plot of sepal width')
plt.show()

# %%
sns.kdeplot(data=df, x='petal_length', hue="species", shade=True)
plt.title('Kurnal density estimation of species')
plt.show()

# %%
sns.histplot(data=df,x='sepal_width',edgecolor= 'black', bins=10,element="step", color='blue') #poly , fill= False
plt.title('Hist Plot of sepal')
plt.show()

# %%
#sns.pairplot(df , kind = "scatter")
sns.pairplot(df, hue='species', diag_kind="hist")
plt.suptitle('Pairplot of Numerical Variables by species', y=1.02, x=0.5)
plt.show()

# %%
Num = df.select_dtypes(include=['int','float']).columns.tolist()
Num
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
correlation_matrix = df[Num].corr()
correlation_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.118129      0.873738     0.820620
# sepal_width      -0.118129     1.000000     -0.426028    -0.362894
# petal_length      0.873738    -0.426028      1.000000     0.962772
# petal_width       0.820620    -0.362894      0.962772     1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='PuBu')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.violinplot(data=df, y='sepal_width', split=False, inner_kws=dict(box_width=15, whis_width=2), palette='Set2')
plt.title('Violin Plot of sepal', color='blue', fontsize=16, fontweight='bold')
plt.show()

# %%
x= 'petal_length'
y = 'sepal_width'
sns.jointplot(x=x, y=y, kind='scatter', data = df, color='red') 
plt.show()

# %%
sns.set_style("whitegrid")


sns.swarmplot(x='petal_length', y='sepal_width',hue='species', data=df, size=10, legend=True, marker='*')  
plt.legend(loc='upper left')

plt.show()

# %%
sns.set(font_scale=1)

# Create a striplot
sns.stripplot(data=df, x='petal_length', y='sepal_width', hue= 'species', size=10)  # size is used for marker size

# Show the plot
plt.show()
